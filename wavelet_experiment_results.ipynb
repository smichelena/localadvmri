# %%
import pandas as pd
import pickle

# %%
results = pd.read_pickle('./results/exp_grid_attack_quant_wavelet_radial40_width10.p')

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 4 entries, 0.0 to 0.1
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Xrec         4 non-null      object
#  1   Yadv         4 non-null      object
#  2   Xadv         4 non-null      object
#  3   Rho0         4 non-null      object
#  4   sel_locs     4 non-null      object
#  5   width_loc    4 non-null      int64
#  6   n_locs       4 non-null      object
#  7   attack_iter  4 non-null      int64
# dtypes: int64(2), object(6)
# memory usage: 288.0+ bytes

# %%
import plot_utils
import matplotlib.pyplot as plt
import numpy as np

# %%
noise_rel = [0.0, 0.01, 0.04, 0.1]

# %%
batch_n = 23
xrec = results["Xrec"][0.04][batch_n,...]
xadv = results["Xadv"][0.04][batch_n,...]
rho = results["Rho0"][0.04][batch_n,...]

# %%
# plt.figure()
count = 0
for eta in noise_rel:
    plt.figure(figsize=(8, 6))

    rho = results["Rho0"][eta][batch_n, ...]
    norm_rho = np.linalg.norm(plot_utils.modulus(rho), ord=np.inf)

    plt.subplot(1, 2, 1)
    plt.imshow(plot_utils.modulus(results["Xrec"][eta][batch_n, ...]), cmap="gray")
    plt.title(r"$rec_{W_{\psi}}(Y)$" + " " + "$\eta=$" + str(eta))

    plt.subplot(1, 2, 2)
    plt.imshow(plot_utils.modulus(results["Xadv"][eta][batch_n, ...]), cmap="gray")
    plt.title(
        r"$rec_{W_{\psi}}(Yadv) $"
        + " "
        + "$\eta=$"
        + str(eta)
        + " "
        + r"$||\rho||_{\infty} = $"
        + " "
        + str(norm_rho)
    )
